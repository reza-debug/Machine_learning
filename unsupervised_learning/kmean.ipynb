# %%
#داده بسازیم
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples=300,n_features=2,centers=3)

# %%
#show data
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],color='blue')
plt.show()

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3)
model.fit(X)
# Out:
# c:\Users\T.acer\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
#add variable for centers and labels
centers = model.cluster_centers_
labels = model.labels_

# %%
#show plot labels
plt.scatter(X[:,0],X[:,1],c=labels)
#show center of cluster
plt.scatter(centers[:,0],centers[:,1],c='red', marker='*')

# %%
X
# Out:
# array([[ -8.8046144 ,  -4.10259882],
#        [ -7.1122187 ,  -4.59429365],
#        [-10.32798052,  11.34751181],
#        [ -5.83616705,  -4.3226193 ],
#        [ -5.95508933,  -6.36304481],
#        [ -1.71402642,  -6.06729183],
#        [-10.2712397 ,   9.66859286],
#        [ -8.11294395,  -4.82982114],
#        [ -1.74301217,  -7.10732462],
#        [ -7.22678058,  -2.93351801],
#        [ -1.66316657,  -4.38289701],
#        [ -9.07233667,  11.43730185],
#        [ -8.43875759,  -3.70374183],
#        [ -9.2850337 ,   9.41238381],
#        [ -2.23428916,  -6.13089392],
#        [-10.99767557,  10.91026906],
#        [ -8.53896856,  -4.87146957],
#        [ -6.44372181,  -5.39614006],
#        [ -8.65726603,   7.47049753],
#        [ -6.80228204,  -4.37922503],
#        [ -6.37337771,  -4.21334533],
#        [ -9.21987482,  10.81052738],
#        [ -7.20971884,  -4.21796518],
#        [ -5.8812248 ,  -4.57446765],
#        [ -0.70567911,  -3.886064  ],
# ...

# %%
#ehtiaj be motale bishtar
pred = model.predict([[-7.0,3.0]])
pred
# Out:
# array([2])

# %%
y
# Out:
# array([0, 0, 2, 0, 0, 1, 2, 0, 1, 0, 1, 2, 0, 2, 1, 2, 0, 0, 2, 0, 0, 2,
#        0, 0, 1, 2, 0, 2, 1, 2, 0, 0, 0, 2, 1, 0, 2, 0, 2, 0, 0, 0, 0, 0,
#        2, 0, 2, 2, 2, 2, 2, 1, 1, 1, 0, 0, 1, 0, 1, 1, 1, 0, 0, 2, 2, 1,
#        2, 2, 1, 1, 2, 0, 2, 1, 0, 1, 0, 1, 1, 1, 1, 1, 1, 1, 2, 2, 2, 0,
#        2, 0, 2, 1, 1, 0, 0, 1, 0, 0, 2, 2, 2, 1, 2, 2, 1, 2, 0, 2, 0, 0,
#        2, 2, 1, 2, 0, 2, 0, 0, 0, 0, 1, 1, 1, 2, 2, 1, 1, 0, 0, 2, 1, 0,
#        0, 1, 2, 0, 1, 0, 2, 1, 2, 1, 2, 2, 0, 2, 2, 1, 1, 1, 2, 0, 1, 0,
#        2, 2, 2, 2, 0, 1, 0, 2, 2, 1, 1, 1, 0, 2, 2, 2, 2, 2, 0, 0, 1, 1,
#        2, 2, 0, 1, 1, 2, 0, 2, 2, 0, 2, 0, 0, 1, 1, 0, 2, 2, 0, 0, 2, 0,
#        2, 1, 1, 2, 1, 2, 2, 1, 0, 0, 1, 1, 2, 1, 1, 0, 0, 1, 0, 0, 0, 2,
#        2, 2, 0, 1, 1, 0, 2, 1, 0, 1, 1, 2, 0, 1, 0, 0, 2, 2, 0, 1, 0, 0,
#        1, 1, 1, 0, 1, 0, 0, 0, 2, 2, 1, 2, 1, 1, 0, 0, 2, 1, 2, 1, 1, 2,
#        0, 1, 1, 0, 1, 0, 1, 1, 2, 0, 1, 1, 1, 1, 1, 2, 2, 1, 2, 1, 1, 0,
# ...
